# %%
import pandas as pd 
import numpy as np
import sqlite3
import matplotlib.pyplot as plt

# %%
path = "/Users/phoebeclark/Desktop/viirs-snpp_2021_United_States.csv"
dfSat = pd.read_csv(path)

# %%
#BEN
#round the lat and long to align with project
dfSat['latitude_rounded'] = round(dfSat['latitude'], 2)
dfSat['longitude_rounded'] = round(dfSat['longitude'], 2)

# %%
#BEN
#split up the aqc date into year, month, day
dfSat['acq_date'] = dfSat['acq_date'].astype('str').str.split(pat = '-')

# %%
#BEN
##seperating out year month day into seperate columns 
dfSat['year'] = pd.DataFrame(dfSat.acq_date.tolist())[0]
dfSat['month'] = pd.DataFrame(dfSat.acq_date.tolist())[1]
dfSat['day'] = pd.DataFrame(dfSat.acq_date.tolist())[2]

# %%
#BEN
#now ge the weather data based on coordinates and date  
#start by creating the columns i want filled out related to the meteostat output
import numpy as np
dfSat['tavg'] = np.nan
dfSat['tmin'] = np.nan
dfSat['tmax'] = np.nan
dfSat['prcp'] = np.nan
dfSat['snow'] = np.nan
dfSat['wdir'] = np.nan
dfSat['wspd'] = np.nan
dfSat['wpgt'] = np.nan
dfSat['pres'] = np.nan
dfSat['tsun'] = np.nan

# %%
#BEN
#create a function to get the weather 
#again, documemntation from this library: https://dev.meteostat.net/python/
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

# %%
#BEN
#the function below gets the weather data for a specific coordinate and date
#it returns a list of [0]tavg, [1]tmin, [2]tmax, [3]prcp, [4]snow, [5]wdir, [6]wspd, [7]wpgt, [8]pres, [9]tsun
def GetWeather(lat, lon, year, month, day):
    start = datetime(year, month, day)
    end = datetime(year, month, day)
    coord = Point(lat, lon)
    data = Daily(coord, start, end)
    data = data.fetch()
    #print(data)
    #print(data.iloc[0, 0])
    #get a list of results
    counter = list(range(0,10)) #list 0-9
    WeatherData = [] #this list serves as a list for data values [0]tavg, [1]tmin, [2]tmax, [3]prcp, [4]snow, [5]wdir, [6]wspd, [7]wpgt, [8]pres, [9]tsun
    try:
        for i in counter:
            WeatherData.append(data.iloc[0, i])
    except:
        WeatherData = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan]    
    print(data)
    return(WeatherData)

# %%
 #BEN
#now populate the weather data for each FIRMS observation 
rowcount = 0 #this will serve as a counter for us to see the progress, if we want 
dfSatTest = dfSat.iloc[:100] #created a small test df if you want to use it
#WARNING: if you just want to test this out I recommend replacing "dfSat" with "dfSatTest" in the 'for' loop below to only run the script on the first 100 rows of the export
for index, row in dfSat.iterrows():
    print("Currently on index " + str(rowcount) + ". Weather result is:") #this tracks progress as the script runs, comment it out if you want
    latx = row['latitude_rounded']
    longx = row['longitude_rounded']
    yrx = int(row['year'])
    monthx = int(row['month'])
    dayx = int(row['day'])
    WeatherList = GetWeather(latx, longx, yrx, monthx, dayx)
    #list contents: [0]tavg, [1]tmin, [2]tmax, [3]prcp, [4]snow, [5]wdir, [6]wspd, [7]wpgt, [8]pres, [9]tsun
    dfSat.at[index, 'tavg'] = WeatherList[0]
    dfSat.at[index, 'tmin'] = WeatherList[1]
    dfSat.at[index, 'tmax'] = WeatherList[2]
    dfSat.at[index, 'prcp'] = WeatherList[3]
    dfSat.at[index, 'snow'] = WeatherList[4]
    dfSat.at[index, 'wdir'] = WeatherList[5]
    dfSat.at[index, 'wspd'] = WeatherList[6]
    dfSat.at[index, 'wpgt'] = WeatherList[7]
    dfSat.at[index, 'pres'] = WeatherList[8]
    dfSat.at[index, 'tsun'] = WeatherList[9]
    rowcount = rowcount + 1
# Out:
# Currently on index 0. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01  -1.6  -3.9   1.1   1.0  50.0  350.0   4.9   NaN  1029.6   NaN
# Currently on index 1. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01  -2.9  -6.7   0.0   0.9   NaN   6.0   0.8   NaN  1030.3   NaN
# Currently on index 2. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01  -2.1  -6.0   0.5   2.4   NaN   8.0   2.8   NaN  1024.8   NaN
# Currently on index 3. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   1.1  -3.8   4.4  21.8   0.0   NaN  12.2   NaN   NaN   NaN
# Currently on index 4. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 5. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01  -2.1  -6.0   0.5   2.4   NaN   8.0   2.8   NaN  1024.8   NaN
# Currently on index 6. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 7. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   1.8  -1.2   4.2  17.3   0.0  28.0   9.7   NaN  1029.1   NaN
# Currently on index 8. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   0.4  -3.9   3.9  21.1   NaN  19.0   9.5   NaN  1028.0   NaN
# Currently on index 9. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01  -0.7  -4.9   1.1  17.5   0.0  26.0   5.0   NaN  1028.4   NaN
# Currently on index 10. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 11. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01  -0.4  -6.0   8.3   0.0   NaN  246.0  16.6   NaN  1017.0   NaN
# Currently on index 12. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   1.3  -3.2   6.7   0.0   0.0  237.0  26.3   NaN  1017.9   NaN
# Currently on index 13. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   1.3  -3.2   6.7   0.0   0.0  237.0  26.3   NaN  1017.9   NaN
# Currently on index 14. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 15. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 16. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp   snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01  -7.5 -16.6   0.0   0.3  130.0  17.0   3.2   NaN  1024.5   NaN
# Currently on index 17. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 18. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 19. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 20. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   8.9   5.6  13.3   NaN   NaN  280.0  10.0   NaN   NaN   NaN
# Currently on index 21. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   8.9   5.6  13.3   NaN   NaN  280.0  10.0   NaN   NaN   NaN
# Currently on index 22. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   1.5  -0.9   3.1   NaN   NaN  315.0  13.6   NaN   NaN   NaN
# Currently on index 23. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   8.7   5.2  13.9   NaN   NaN  274.0  14.7   NaN   NaN   NaN
# Currently on index 24. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   1.0  -3.8   8.0   NaN   NaN  298.0   8.0   NaN   NaN   NaN
# Currently on index 25. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 26. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   8.7   5.2  13.9   NaN   NaN  274.0  14.7   NaN   NaN   NaN
# Currently on index 27. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   8.9   5.6  13.3   NaN   NaN  280.0  10.0   NaN   NaN   NaN
# Currently on index 28. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01  11.5   7.5  15.5   NaN   NaN  257.0  13.3   NaN   NaN   NaN
# Currently on index 29. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 30. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   8.9   5.6  13.3   NaN   NaN  280.0  10.0   NaN   NaN   NaN
# Currently on index 31. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   9.7   5.5  12.6   NaN   NaN  254.0  12.6   NaN   NaN   NaN
# Currently on index 32. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   8.9   5.6  13.3   NaN   NaN  280.0  10.0   NaN   NaN   NaN
# Currently on index 33. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 34. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   9.7   5.5  12.6   NaN   NaN  254.0  12.6   NaN   NaN   NaN
# Currently on index 35. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 36. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   8.9   5.6  13.3   NaN   NaN  280.0  10.0   NaN   NaN   NaN
# Currently on index 37. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   9.7   5.5  12.6   NaN   NaN  254.0  12.6   NaN   NaN   NaN
# Currently on index 38. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 39. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 40. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 41. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 42. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   6.3   2.8  10.8   NaN   NaN  307.0  12.7   NaN   NaN   NaN
# Currently on index 43. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01  -0.5  -6.0   5.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Currently on index 44. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 45. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   7.4   4.0  12.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Currently on index 46. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   7.4   4.0  12.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Currently on index 47. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 48. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   7.4   4.0  12.0   0.0   0.0  288.0  15.8   NaN  1015.7   NaN
# Currently on index 49. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   7.4   4.0  12.0   0.0   0.0  275.0  17.3   NaN  1016.4   NaN
# Currently on index 50. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01  -0.5  -6.0   5.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Currently on index 51. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 52. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   7.4   4.0  12.0   0.0   0.0  275.0  17.3   NaN  1016.4   NaN
# Currently on index 53. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   7.4   4.0  12.0   0.0   0.0  275.0  17.3   NaN  1016.4   NaN
# Currently on index 54. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 55. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   7.4   4.0  12.0   0.0   0.0  275.0  17.3   NaN  1016.4   NaN
# Currently on index 56. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   7.4   4.0  12.0   0.0   0.0  275.0  17.3   NaN  1016.4   NaN
# Currently on index 57. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01  -0.5  -6.0   5.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Currently on index 58. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 59. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   8.3   4.4  13.3   0.0   0.0  275.0  17.3   NaN  1016.4   NaN
# Currently on index 60. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 61. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   9.8   5.0  11.1   0.0   NaN  261.0  15.1   NaN  1015.8   NaN
# Currently on index 62. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   4.2   0.8  10.6   NaN   NaN  318.0  17.0   NaN   NaN   NaN
# Currently on index 63. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   4.2   0.8  10.6   NaN   NaN  318.0  17.0   NaN   NaN   NaN
# Currently on index 64. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01  -0.3  -2.1   5.6  17.0   0.0  94.0  13.3   NaN  1021.7   NaN
# Currently on index 65. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 66. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   8.7   5.6  13.3   0.0   0.0  276.0  18.4   NaN  1016.2   NaN
# Currently on index 67. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   8.7   5.6  13.3   0.0   0.0  276.0  18.4   NaN  1016.2   NaN
# Currently on index 68. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 69. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   8.7   5.6  13.3   0.0   0.0  276.0  18.4   NaN  1016.2   NaN
# Currently on index 70. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   8.7   5.6  13.3   0.0   0.0  276.0  18.4   NaN  1016.2   NaN
# Currently on index 71. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01  -1.1  -5.9   1.0   NaN   NaN  27.0   4.3   NaN   NaN   NaN
# Currently on index 72. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   9.8   5.0  11.1   0.0   NaN  261.0  15.1   NaN  1015.8   NaN
# Currently on index 73. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   8.7   5.6  13.3   0.0   0.0  276.0  18.4   NaN  1016.2   NaN
# Currently on index 74. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   7.3   1.7  14.4   0.0   0.0  308.0  15.5   NaN  1016.1   NaN
# Currently on index 75. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   8.2   3.9  12.2   0.0   NaN  264.0  15.5   NaN  1015.0   NaN
# Currently on index 76. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   7.3   1.7  14.4   0.0   0.0  308.0  15.5   NaN  1016.1   NaN
# Currently on index 77. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 78. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01  -1.6  -6.1   0.6   NaN   NaN  27.0   4.3   NaN   NaN   NaN
# Currently on index 79. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   8.9   5.6  13.3   NaN   NaN  280.0  10.0   NaN   NaN   NaN
# Currently on index 80. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   4.2   0.8  10.6   NaN   NaN  318.0  17.0   NaN   NaN   NaN
# Currently on index 81. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 82. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   0.9  -6.7   9.4   0.0   NaN   NaN   9.5   NaN   NaN   NaN
# Currently on index 83. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   7.3   1.7  14.4   0.0   NaN  308.0  15.5   NaN  1016.1   NaN
# Currently on index 84. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   7.3   1.7  14.4   0.0   NaN  308.0  15.5   NaN  1016.1   NaN
# Currently on index 85. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01  -1.1  -5.9   1.0   NaN   NaN  27.0   4.3   NaN   NaN   NaN
# Currently on index 86. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   9.8   5.0  11.1   0.0   NaN  261.0  15.1   NaN  1015.8   NaN
# Currently on index 87. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 88. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 89. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   6.8   3.3  10.6   NaN   NaN  283.0  17.9   NaN  1015.6   NaN
# Currently on index 90. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 91. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   6.9   2.5  11.6   0.0   NaN  300.0  13.8   NaN  1016.3   NaN
# Currently on index 92. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01  -1.6  -6.1   0.6   NaN   NaN  27.0   4.3   NaN   NaN   NaN
# Currently on index 93. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   1.0  -3.8   8.0   0.0   NaN  298.0   8.0   NaN   NaN   NaN
# Currently on index 94. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   6.9   2.5  11.6   0.0   NaN  300.0  13.8   NaN  1016.3   NaN
# Currently on index 95. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   7.5   3.9  12.8   0.0   NaN   NaN  11.1   NaN  1016.3   NaN
# Currently on index 96. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   9.1   5.7  13.6   0.0   NaN  263.0  13.6   NaN  1015.8   NaN
# Currently on index 97. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   7.5   3.9  12.8   0.0   NaN   NaN  11.1   NaN  1016.3   NaN
# Currently on index 98. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 99. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01  -1.1  -5.9   1.0   NaN   NaN  27.0   4.3   NaN   NaN   NaN
# Currently on index 100. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   9.1   5.7  13.6   0.0   NaN  263.0  13.6   NaN  1015.8   NaN
# Currently on index 101. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   8.8   5.0  14.2   NaN   NaN  309.0  15.9   NaN   NaN   NaN
# Currently on index 102. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 103. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 104. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 105. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   8.4   1.1  16.1   0.0   NaN  316.0  12.8   NaN  1017.7   NaN
# Currently on index 106. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01  -1.1  -5.9   1.0   7.9  25.0  45.0  10.2   NaN  1017.7   NaN
# Currently on index 107. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   9.1   5.7  13.6   0.0   NaN  263.0  13.6   NaN  1015.8   NaN
# Currently on index 108. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   8.4   1.1  16.1   0.0   NaN  316.0  12.8   NaN  1017.7   NaN
# Currently on index 109. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   8.4   1.1  16.1   0.0   NaN  316.0  12.8   NaN  1017.7   NaN
# Currently on index 110. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01  13.0  10.6  14.4   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Currently on index 111. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 112. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   9.9   4.6  14.9   0.0   0.0  338.0  12.2   NaN  1017.3   NaN
# Currently on index 113. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01  -1.1  -5.9   1.0   NaN   NaN  27.0   4.3   NaN   NaN   NaN
# Currently on index 114. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   9.1   5.7  13.6   0.0   NaN  263.0  13.6   NaN  1015.8   NaN
# Currently on index 115. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   9.9   4.6  14.9   0.0   0.0  338.0  12.2   NaN  1017.3   NaN
# Currently on index 116. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   9.9   4.6  14.9   0.0   0.0  338.0  12.2   NaN  1017.3   NaN
# Currently on index 117. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   9.1   5.7  13.6   0.0   NaN  263.0  13.6   NaN  1015.8   NaN
# Currently on index 118. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   9.9   4.6  14.9   NaN   NaN  338.0  12.2   NaN   NaN   NaN
# Currently on index 119. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 120. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   9.1   5.7  13.6   0.0   NaN  263.0  13.6   NaN  1015.8   NaN
# Currently on index 121. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-01   9.1   5.7  13.6   0.0   NaN  263.0  13.6   NaN  1015.8   NaN
# Currently on index 122. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 123. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 124. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 125. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 126. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 127. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 128. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 129. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 130. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 131. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 132. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 133. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 134. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01  -0.5  -6.0   5.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Currently on index 135. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01  -0.5  -6.0   5.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Currently on index 136. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01  -0.5  -6.0   5.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Currently on index 137. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   0.2  -6.7   3.3   0.0   NaN   NaN  20.0   NaN   NaN   NaN
# Currently on index 138. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   0.2  -6.7   3.3   0.0   NaN   NaN  20.0   NaN   NaN   NaN
# Currently on index 139. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun
# time
# 2021-01-01   0.2  -6.7   3.3   0.0   NaN   NaN  20.0   NaN   NaN   NaN
# Currently on index 140. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# Warning: Cannot load daily/KU780.csv.gz from https://bulk.meteostat.net/v2/
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
# time
# 2021-01-06  14.5   8.9  21.1   0.0   NaN   3.0   6.7   NaN  1019.9   NaN
# Currently on index 3130. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06  13.4   7.2  20.6   0.0   NaN  338.0   9.8   NaN  1019.5   NaN
# Currently on index 3131. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06  13.4   7.2  20.6   0.0   NaN  338.0   9.8   NaN  1019.5   NaN
# Currently on index 3132. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06  13.4   7.2  20.6   0.0   NaN  338.0   9.8   NaN  1019.5   NaN
# Currently on index 3133. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06  12.7   6.7  19.4   0.0   NaN   1.0   8.0   NaN  1020.0   NaN
# Currently on index 3134. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06  13.4   7.2  20.6   0.0   0.0  338.0   9.8   NaN  1019.5   NaN
# Currently on index 3135. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06  13.4   7.2  20.6   0.0   0.0  338.0   9.8   NaN  1019.5   NaN
# Currently on index 3136. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   9.3   2.0  19.0   0.0   NaN   7.0   2.0   NaN  1020.2   NaN
# Currently on index 3137. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   9.3   2.0  19.0   0.0   NaN   7.0   2.0   NaN  1020.2   NaN
# Currently on index 3138. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   9.3   2.0  19.0   0.0   NaN   7.0   2.0   NaN  1020.2   NaN
# Currently on index 3139. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06  10.1   1.7  18.9   0.0   NaN  12.0   3.2   NaN  1020.5   NaN
# Currently on index 3140. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 3141. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06  11.7   6.1  16.7   0.0   NaN  347.0  14.0   NaN  1020.4   NaN
# Currently on index 3142. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   7.8  -0.5  18.3   0.0   NaN   3.0   3.2   NaN  1020.7   NaN
# Currently on index 3143. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   9.8   2.0  18.0   0.0   NaN  27.0   8.0   NaN  1020.6   NaN
# Currently on index 3144. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   9.8   2.0  18.0   0.0   NaN  27.0   8.0   NaN  1020.6   NaN
# Currently on index 3145. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   9.8   2.0  18.0   0.0   NaN  27.0   8.0   NaN  1020.6   NaN
# Currently on index 3146. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06  10.0   1.0  19.0   0.0   NaN  28.0   9.1   NaN  1020.9   NaN
# Currently on index 3147. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06  10.0   1.0  19.0   0.0   NaN  28.0   9.1   NaN  1020.9   NaN
# Currently on index 3148. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   9.5   3.0  16.0   0.0   NaN  40.0   8.9   NaN  1020.9   NaN
# Currently on index 3149. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   8.9   3.5  15.6   0.0   NaN  39.0   7.8   NaN  1021.0   NaN
# Currently on index 3150. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   8.9   3.5  15.6   0.0   NaN  39.0   7.8   NaN  1021.0   NaN
# Currently on index 3151. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 3152. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 3153. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 3154. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06  10.6   6.6  15.3   0.0   NaN  38.0   8.2   NaN  1021.1   NaN
# Currently on index 3155. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06  10.6   6.6  15.3   0.0   NaN  38.0   8.2   NaN  1021.1   NaN
# Currently on index 3156. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   8.8   3.9  15.0   0.0   NaN  18.0   9.8   NaN  1021.4   NaN
# Currently on index 3157. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   8.8   3.9  15.0   0.0   NaN  18.0   9.8   NaN  1021.4   NaN
# Currently on index 3158. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   8.8   3.9  15.0   0.0   NaN  18.0   9.8   NaN  1021.4   NaN
# Currently on index 3159. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   8.8   3.9  15.0   0.0   NaN  18.0   9.8   NaN  1021.4   NaN
# Currently on index 3160. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   7.2   0.0  15.0   0.0   NaN  34.0   8.8   NaN  1021.8   NaN
# Currently on index 3161. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   8.2   3.2  15.0   0.0   NaN  13.0   4.0   NaN  1021.9   NaN
# Currently on index 3162. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   7.2   0.0  15.0   0.0   NaN  34.0   8.8   NaN  1021.8   NaN
# Currently on index 3163. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   7.2   0.0  15.0   0.0   NaN  34.0   8.8   NaN  1021.8   NaN
# Currently on index 3164. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   7.2   0.0  15.0   0.0   NaN  34.0   8.8   NaN  1021.8   NaN
# Currently on index 3165. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   7.2   0.0  15.0   0.0   NaN  34.0   8.8   NaN  1021.8   NaN
# Currently on index 3166. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   7.2   0.0  15.0   0.0   NaN  34.0   8.8   NaN  1021.8   NaN
# Currently on index 3167. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   7.2   0.0  15.0   0.0   NaN  34.0   8.8   NaN  1021.8   NaN
# Currently on index 3168. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   7.2   0.0  15.0   0.0   NaN  34.0   8.8   NaN  1021.8   NaN
# Currently on index 3169. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   5.6  -0.8  13.7   0.0   NaN   9.0   1.0   NaN  1022.1   NaN
# Currently on index 3170. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   5.6  -0.8  13.7   0.0   NaN   9.0   1.0   NaN  1022.1   NaN
# Currently on index 3171. Weather result is:
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun]
# Index: []
# Currently on index 3172. Weather result is:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   8.4   3.0  14.0   0.0   NaN  18.0   6.1   NaN  1021.9   NaN
# Currently on index 3173. Weather result is:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-01-06   7.8   4.0  13.0   0.0   0.0  358.0   1.4   NaN  1021.5   NaN
# Currently on index 3174. Weather result is:
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
#Can we seperate long/lats into city/state/county?
# import module
from geopy.geocoders import Nominatim

# %%
# initialize Nominatim API 
geolocator = Nominatim(user_agent="geoapiExercises")

# %%
# Latitude & Longitude input
#Using row 0 as an example
Latitude = "43.476295"
Longitude = "-71.587440"
  
location = geolocator.reverse(Latitude+","+Longitude)
  

print(location)

# %%
#Again, using row 0 as an example
address = location.raw['address']
print(address)

# %%
city = address.get('city', '')
state = address.get('state', '')
country = address.get('country', '')
code = address.get('country_code')
zipcode = address.get('postcode')
print('City : ',city)
print('State : ',state)
print('Country : ',country)
print('Zip Code : ', zipcode)

# %%
#Imports
import reverse_geocoder as rg 
import pprint

# %%
#Identifying city, state, and county info for each long/lat pair
def reverseGeocode(coordinates): 
    result = rg.search(coordinates)
    # result is a list containing ordered dictionary. 
    pprint.pprint(result)  

# Driver function 
if __name__=="__main__": 

    for i in range(2):
        #For first 2 lines only
        coordinates =(dfSat['latitude'][i],dfSat['longitude'][i])
        reverseGeocode(coordinates)

# %%
print(len(dfSat.index))

# %%
#Finding City, State, County data for all data
def reverseGeocode(coordinates): 
    result = rg.search(coordinates)

if __name__=="__main__": 
#For all data in dataframe
    for i in range(661058):
        coordinates =(dfSat['latitude'][i],dfSat['longitude'][i])
        reverseGeocode(coordinates)

# %%
#Creating columns for location data
dfSat['name'] = np.nan
dfSat['admin1'] = np.nan
dfSat['admin2'] = np.nan

# %%
dfSat = dSat.copy().rename(columns={ 'admin1': 'State'})
dfSat = dfSat.copy().rename(columns={ 'admin2': 'County'})
dfSat = dfSat.copy().rename(columns={ 'name': 'City'})
